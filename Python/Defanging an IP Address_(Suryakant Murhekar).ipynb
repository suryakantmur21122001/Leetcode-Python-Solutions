# %% [markdown]
# # **Name - Suryakant Murhekar**
# # **Batch - 350**

# %% [markdown]
# # Problem: Defanging an IP Address
#
# ## **Task:-**
#
# Given a valid (IPv4) IP address, return a defanged version of that IP address.
#
# A defanged IP address replaces every period "." with "[.]".
#
# Example 1:
#
# Input: address = "1.1.1.1"
#
# Output: "1[.]1[.]1[.]1"
#
# Example 2:
#
# Input: address = "255.100.50.0"
#
# Output: "255[.]100[.]50[.]0"
#
# ## Plateform: HackerRank

# %%
class Solution:
    def defangIPaddr(self, address: str) -> str:
        return address.replace(".", "[.]")

sol = Solution()
address1 = "1.1.1.1"
address2 = "255.100.50.0"
print(sol.defangIPaddr(address1))
print(sol.defangIPaddr(address2))
# Out:
# 1[.]1[.]1[.]1
# 255[.]100[.]50[.]0
